# %%
# !pip install pyperclip
pyperclip.copy('中文')
pyperclip.paste()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().system('pip install pyperclip')
# ----> 2 pyperclip.copy('中文')
#       3 pyperclip.paste()
#
# NameError: name 'pyperclip' is not defined

# %%
support
